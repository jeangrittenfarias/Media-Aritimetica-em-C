# %% [markdown]
# <a href="https://colab.research.google.com/github/jeangrittenfarias/M-dia-Aritim-tica-em-C/blob/main/M%C3%A9dia_Aritim%C3%A9tica_em_C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%writefile teste.cpp
#
#
# #include <stdio.h>
# /*
# Program aque calcula a média aritmética
# Obter as 2 notas de provas
# Calcular a média aritmética
# Se a média for igual ou maior que 7, o aluno foi aprovado
# senão ele foi reprovado
# */
# int main(void) {
# //declaração de variável
# float nota1, nota2, media;
#
# //Obter as 2 notas de provas
#   printf("Digite a primeira nota:  ");
#   scanf("%f", &nota1);
#
#   printf("Digite a segunda  nota:  ");
#   scanf("%f", &nota2);
#
# //Calcular a média aritmética
#   media = (nota1 + nota2)/2;
#
# //mostro o resultado
# if (media >= 7 )
#   printf("Aprovado! \n");
# else
#   printf("Reprovado! \n");
#
#   return 0;
# }

# %%
! g++ teste.cpp -o testec

# %%
! ./testec
# Out:
# Digite a primeira nota:  ^C
